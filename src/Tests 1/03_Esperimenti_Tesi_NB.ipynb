# %% [markdown]
# # **NAIVE BAYES**

# %%
from utils import *

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, f1_score, confusion_matrix

# %%
# Ignore warnings for cleaner output
import warnings
warnings.filterwarnings("ignore")

# %%
# -----------------------
# Model building function
# -----------------------

def build_model(alpha=1.0, fit_prior=False):
    """
    Builds a scikit-learn Pipeline with TF-IDF vectorization and Multinomial Naive Bayes classifier.

    Args:
        alpha (float): Smoothing parameter for Multinomial Naive Bayes.
        fit_prior (bool): Whether to learn class prior probabilities.

    Returns:
        Pipeline: A scikit-learn Pipeline object (TF-IDF + Multinomial Naive Bayes).
    """
    return Pipeline([
        ('tfidf', TfidfVectorizer(  # TD-IDF vectorization inside pipeline
            max_features=5000,      # limit to top 5000 features
            ngram_range=(1, 2),     # unigrams + bigrams
            stop_words="english"    # remove English stop words
        )),
        ('clf', MultinomialNB(      # Multinomial Naive Bayes classifier
            alpha=alpha,
            fit_prior=fit_prior
        ))
    ])

# %% [markdown]
# ## VERSION 1: Dataset (Simple)

# %%
dataset_df = data_loading()

for name, df in dataset_df.items():
    print(f"Dataset: {name}, Number of samples: {len(df)}")
# Out:
# Dataset: Celebrity, Number of samples: 500
# Dataset: CIDII, Number of samples: 722
# Dataset: FaKES, Number of samples: 842
# Dataset: FakeVsSatire, Number of samples: 486
# Dataset: Horne, Number of samples: 326
# Dataset: Infodemic, Number of samples: 10559
# Dataset: ISOT, Number of samples: 44271
# Dataset: Kaggle_clement, Number of samples: 39105
# Dataset: Kaggle_meg, Number of samples: 12845
# Dataset: LIAR_PLUS, Number of samples: 12784
# Dataset: Politifact, Number of samples: 504
# Dataset: Unipi_NDF, Number of samples: 554

# %%
# --------------------------------
# Fine-tuning on multiple datasets
# --------------------------------

datasets = {name: split_dataset(df) for name, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (name, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on {name} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after {name}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after {name}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after {name}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all datasets
    print("\n--- Evaluation on all datasets ---")
    results[name] = {}
    for test_name, test_data in datasets.items(): # for each dataset
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[name][test_name] = f1
        print(f"Evaluation on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# === Phase 1: Training/Fine-tuning on Celebrity ===
# Classification Report after Celebrity:
#               precision    recall  f1-score   support
#
#            0       0.60      0.76      0.67        50
#            1       0.68      0.50      0.57        50
#
#     accuracy                           0.63       100
#    macro avg       0.64      0.63      0.62       100
# weighted avg       0.64      0.63      0.62       100
#
# Confusion Matrix after Celebrity:
# [[38 12]
#  [25 25]]
#
# Weighted F1-score after Celebrity: 0.6236395076797884
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.6236
# Evaluation on CIDII: Weighted F1 = 0.5914
# Evaluation on FaKES: Weighted F1 = 0.3956
# Evaluation on FakeVsSatire: Weighted F1 = 0.3488
# Evaluation on Horne: Weighted F1 = 0.5320
# Evaluation on Infodemic: Weighted F1 = 0.5376
# Evaluation on ISOT: Weighted F1 = 0.3772
# Evaluation on Kaggle_clement: Weighted F1 = 0.4287
# Evaluation on Kaggle_meg: Weighted F1 = 0.9009
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5222
# Evaluation on Politifact: Weighted F1 = 0.6100
# Evaluation on Unipi_NDF: Weighted F1 = 0.5009
#
# === Phase 2: Training/Fine-tuning on CIDII ===
# Classification Report after CIDII:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96        85
#            1       0.95      0.93      0.94        60
#
#     accuracy                           0.95       145
#    macro avg       0.95      0.95      0.95       145
# weighted avg       0.95      0.95      0.95       145
#
# Confusion Matrix after CIDII:
# [[82  3]
#  [ 4 56]]
#
# Weighted F1-score after CIDII: 0.951662455665872
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5333
# Evaluation on CIDII: Weighted F1 = 0.9517
# Evaluation on FaKES: Weighted F1 = 0.4818
# Evaluation on FakeVsSatire: Weighted F1 = 0.4998
# Evaluation on Horne: Weighted F1 = 0.6197
# Evaluation on Infodemic: Weighted F1 = 0.4743
# Evaluation on ISOT: Weighted F1 = 0.6918
# Evaluation on Kaggle_clement: Weighted F1 = 0.6757
# Evaluation on Kaggle_meg: Weighted F1 = 0.3757
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4859
# Evaluation on Politifact: Weighted F1 = 0.4403
# Evaluation on Unipi_NDF: Weighted F1 = 0.5847
#
# === Phase 3: Training/Fine-tuning on FaKES ===
# Classification Report after FaKES:
#               precision    recall  f1-score   support
#
#            0       0.52      0.67      0.59        89
#            1       0.45      0.30      0.36        80
#
#     accuracy                           0.50       169
#    macro avg       0.49      0.49      0.47       169
# weighted avg       0.49      0.50      0.48       169
#
# Confusion Matrix after FaKES:
# [[60 29]
#  [56 24]]
#
# Weighted F1-score after FaKES: 0.47911089601619866
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4358
# Evaluation on CIDII: Weighted F1 = 0.5006
# Evaluation on FaKES: Weighted F1 = 0.4791
# Evaluation on FakeVsSatire: Weighted F1 = 0.3263
# Evaluation on Horne: Weighted F1 = 0.5341
# Evaluation on Infodemic: Weighted F1 = 0.4384
# Evaluation on ISOT: Weighted F1 = 0.4015
# Evaluation on Kaggle_clement: Weighted F1 = 0.4058
# Evaluation on Kaggle_meg: Weighted F1 = 0.7947
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4936
# Evaluation on Politifact: Weighted F1 = 0.4851
# Evaluation on Unipi_NDF: Weighted F1 = 0.4275
#
# === Phase 4: Training/Fine-tuning on FakeVsSatire ===
# Classification Report after FakeVsSatire:
#               precision    recall  f1-score   support
#
#            0       0.88      0.54      0.67        41
#            1       0.74      0.95      0.83        57
#
#     accuracy                           0.78        98
#    macro avg       0.81      0.74      0.75        98
# weighted avg       0.80      0.78      0.76        98
#
# Confusion Matrix after FakeVsSatire:
# [[22 19]
#  [ 3 54]]
#
# Weighted F1-score after FakeVsSatire: 0.7621140763997908
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4998
# Evaluation on CIDII: Weighted F1 = 0.3641
# Evaluation on FaKES: Weighted F1 = 0.3016
# Evaluation on FakeVsSatire: Weighted F1 = 0.7621
# Evaluation on Horne: Weighted F1 = 0.5003
# Evaluation on Infodemic: Weighted F1 = 0.3929
# Evaluation on ISOT: Weighted F1 = 0.4587
# Evaluation on Kaggle_clement: Weighted F1 = 0.4248
# Evaluation on Kaggle_meg: Weighted F1 = 0.3685
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4300
# Evaluation on Politifact: Weighted F1 = 0.3318
# Evaluation on Unipi_NDF: Weighted F1 = 0.5079
#
# === Phase 5: Training/Fine-tuning on Horne ===
# Classification Report after Horne:
#               precision    recall  f1-score   support
#
#            0       0.73      0.98      0.83        41
#            1       0.91      0.40      0.56        25
#
#     accuracy                           0.76        66
#    macro avg       0.82      0.69      0.69        66
# weighted avg       0.80      0.76      0.73        66
#
# Confusion Matrix after Horne:
# [[40  1]
#  [15 10]]
#
# Weighted F1-score after Horne: 0.7281144781144782
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5022
# Evaluation on CIDII: Weighted F1 = 0.6254
# Evaluation on FaKES: Weighted F1 = 0.4847
# Evaluation on FakeVsSatire: Weighted F1 = 0.4418
# Evaluation on Horne: Weighted F1 = 0.7281
# Evaluation on Infodemic: Weighted F1 = 0.4789
# Evaluation on ISOT: Weighted F1 = 0.4658
# Evaluation on Kaggle_clement: Weighted F1 = 0.5060
# Evaluation on Kaggle_meg: Weighted F1 = 0.8552
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5065
# Evaluation on Politifact: Weighted F1 = 0.6496
# Evaluation on Unipi_NDF: Weighted F1 = 0.5270
#
# === Phase 6: Training/Fine-tuning on Infodemic ===
# Classification Report after Infodemic:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92      1106
#          1.0       0.89      0.95      0.92      1006
#
#     accuracy                           0.92      2112
#    macro avg       0.92      0.92      0.92      2112
# weighted avg       0.92      0.92      0.92      2112
#
# Confusion Matrix after Infodemic:
# [[992 114]
#  [ 51 955]]
#
# Weighted F1-score after Infodemic: 0.9219158392527766
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3333
# Evaluation on CIDII: Weighted F1 = 0.2723
# Evaluation on FaKES: Weighted F1 = 0.3042
# Evaluation on FakeVsSatire: Weighted F1 = 0.4278
# Evaluation on Horne: Weighted F1 = 0.2020
# Evaluation on Infodemic: Weighted F1 = 0.9219
# Evaluation on ISOT: Weighted F1 = 0.3573
# Evaluation on Kaggle_clement: Weighted F1 = 0.2961
# Evaluation on Kaggle_meg: Weighted F1 = 0.0842
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4129
# Evaluation on Politifact: Weighted F1 = 0.2992
# Evaluation on Unipi_NDF: Weighted F1 = 0.2542
#
# === Phase 7: Training/Fine-tuning on ISOT ===
# Classification Report after ISOT:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      4284
#            1       0.97      0.95      0.96      4571
#
#     accuracy                           0.96      8855
#    macro avg       0.96      0.96      0.96      8855
# weighted avg       0.96      0.96      0.96      8855
#
# Confusion Matrix after ISOT:
# [[4144  140]
#  [ 250 4321]]
#
# Weighted F1-score after ISOT: 0.955968026923304
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3552
# Evaluation on CIDII: Weighted F1 = 0.3400
# Evaluation on FaKES: Weighted F1 = 0.3606
# Evaluation on FakeVsSatire: Weighted F1 = 0.5166
# Evaluation on Horne: Weighted F1 = 0.4934
# Evaluation on Infodemic: Weighted F1 = 0.4092
# Evaluation on ISOT: Weighted F1 = 0.9560
# Evaluation on Kaggle_clement: Weighted F1 = 0.9467
# Evaluation on Kaggle_meg: Weighted F1 = 0.3026
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5218
# Evaluation on Politifact: Weighted F1 = 0.5087
# Evaluation on Unipi_NDF: Weighted F1 = 0.3041
#
# === Phase 8: Training/Fine-tuning on Kaggle_clement ===
# Classification Report after Kaggle_clement:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      4240
#            1       0.94      0.95      0.95      3581
#
#     accuracy                           0.95      7821
#    macro avg       0.95      0.95      0.95      7821
# weighted avg       0.95      0.95      0.95      7821
#
# Confusion Matrix after Kaggle_clement:
# [[4039  201]
#  [ 175 3406]]
#
# Weighted F1-score after Kaggle_clement: 0.951937326993894
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3711
# Evaluation on CIDII: Weighted F1 = 0.3529
# Evaluation on FaKES: Weighted F1 = 0.3606
# Evaluation on FakeVsSatire: Weighted F1 = 0.4346
# Evaluation on Horne: Weighted F1 = 0.4099
# Evaluation on Infodemic: Weighted F1 = 0.4320
# Evaluation on ISOT: Weighted F1 = 0.9393
# Evaluation on Kaggle_clement: Weighted F1 = 0.9519
# Evaluation on Kaggle_meg: Weighted F1 = 0.3366
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5329
# Evaluation on Politifact: Weighted F1 = 0.4989
# Evaluation on Unipi_NDF: Weighted F1 = 0.3041
#
# === Phase 9: Training/Fine-tuning on Kaggle_meg ===
# Classification Report after Kaggle_meg:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      2514
#            1       0.06      0.16      0.09        55
#
#     accuracy                           0.93      2569
#    macro avg       0.52      0.55      0.52      2569
# weighted avg       0.96      0.93      0.94      2569
#
# Confusion Matrix after Kaggle_meg:
# [[2371  143]
#  [  46    9]]
#
# Weighted F1-score after Kaggle_meg: 0.9429442020772815
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4323
# Evaluation on CIDII: Weighted F1 = 0.4674
# Evaluation on FaKES: Weighted F1 = 0.3736
# Evaluation on FakeVsSatire: Weighted F1 = 0.2687
# Evaluation on Horne: Weighted F1 = 0.4688
# Evaluation on Infodemic: Weighted F1 = 0.5041
# Evaluation on ISOT: Weighted F1 = 0.3399
# Evaluation on Kaggle_clement: Weighted F1 = 0.4006
# Evaluation on Kaggle_meg: Weighted F1 = 0.9429
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4770
# Evaluation on Politifact: Weighted F1 = 0.6033
# Evaluation on Unipi_NDF: Weighted F1 = 0.4376
#
# === Phase 10: Training/Fine-tuning on LIAR_PLUS ===
# Classification Report after LIAR_PLUS:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.64      0.64      1426
#          1.0       0.55      0.56      0.55      1131
#
#     accuracy                           0.60      2557
#    macro avg       0.60      0.60      0.60      2557
# weighted avg       0.60      0.60      0.60      2557
#
# Confusion Matrix after LIAR_PLUS:
# [[913 513]
#  [501 630]]
#
# Weighted F1-score after LIAR_PLUS: 0.6036500618773164
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4485
# Evaluation on CIDII: Weighted F1 = 0.3165
# Evaluation on FaKES: Weighted F1 = 0.4437
# Evaluation on FakeVsSatire: Weighted F1 = 0.4584
# Evaluation on Horne: Weighted F1 = 0.4649
# Evaluation on Infodemic: Weighted F1 = 0.6063
# Evaluation on ISOT: Weighted F1 = 0.5094
# Evaluation on Kaggle_clement: Weighted F1 = 0.4811
# Evaluation on Kaggle_meg: Weighted F1 = 0.4262
# Evaluation on LIAR_PLUS: Weighted F1 = 0.6037
# Evaluation on Politifact: Weighted F1 = 0.5432
# Evaluation on Unipi_NDF: Weighted F1 = 0.3571
#
# === Phase 11: Training/Fine-tuning on Politifact ===
# Classification Report after Politifact:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        65
#            1       0.83      0.53      0.64        36
#
#     accuracy                           0.79       101
#    macro avg       0.80      0.73      0.75       101
# weighted avg       0.80      0.79      0.78       101
#
# Confusion Matrix after Politifact:
# [[61  4]
#  [17 19]]
#
# Weighted F1-score after Politifact: 0.7786236250743719
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4895
# Evaluation on CIDII: Weighted F1 = 0.6013
# Evaluation on FaKES: Weighted F1 = 0.4710
# Evaluation on FakeVsSatire: Weighted F1 = 0.4444
# Evaluation on Horne: Weighted F1 = 0.5782
# Evaluation on Infodemic: Weighted F1 = 0.5738
# Evaluation on ISOT: Weighted F1 = 0.4890
# Evaluation on Kaggle_clement: Weighted F1 = 0.5240
# Evaluation on Kaggle_meg: Weighted F1 = 0.8547
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4808
# Evaluation on Politifact: Weighted F1 = 0.7786
# Evaluation on Unipi_NDF: Weighted F1 = 0.3951
#
# === Phase 12: Training/Fine-tuning on Unipi_NDF ===
# Classification Report after Unipi_NDF:
#               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88        68
#            1       0.96      0.58      0.72        43
#
#     accuracy                           0.83       111
#    macro avg       0.87      0.78      0.80       111
# weighted avg       0.86      0.83      0.82       111
#
# Confusion Matrix after Unipi_NDF:
# [[67  1]
#  [18 25]]
#
# Weighted F1-score after Unipi_NDF: 0.8172520346433391
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5484
# Evaluation on CIDII: Weighted F1 = 0.3576
# Evaluation on FaKES: Weighted F1 = 0.3124
# Evaluation on FakeVsSatire: Weighted F1 = 0.5493
# Evaluation on Horne: Weighted F1 = 0.3456
# Evaluation on Infodemic: Weighted F1 = 0.5380
# Evaluation on ISOT: Weighted F1 = 0.3986
# Evaluation on Kaggle_clement: Weighted F1 = 0.3703
# Evaluation on Kaggle_meg: Weighted F1 = 0.4740
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5065
# Evaluation on Politifact: Weighted F1 = 0.5996
# Evaluation on Unipi_NDF: Weighted F1 = 0.8173

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for name, res in results.items():
    print(f"\nResults after training on {name}:")
    for test_name, f1 in res.items():
        print(f"  Test on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on Celebrity:
#   Test on Celebrity: Weighted F1 = 0.6236
#   Test on CIDII: Weighted F1 = 0.5914
#   Test on FaKES: Weighted F1 = 0.3956
#   Test on FakeVsSatire: Weighted F1 = 0.3488
#   Test on Horne: Weighted F1 = 0.5320
#   Test on Infodemic: Weighted F1 = 0.5376
#   Test on ISOT: Weighted F1 = 0.3772
#   Test on Kaggle_clement: Weighted F1 = 0.4287
#   Test on Kaggle_meg: Weighted F1 = 0.9009
#   Test on LIAR_PLUS: Weighted F1 = 0.5222
#   Test on Politifact: Weighted F1 = 0.6100
#   Test on Unipi_NDF: Weighted F1 = 0.5009
#
# Results after training on CIDII:
#   Test on Celebrity: Weighted F1 = 0.5333
#   Test on CIDII: Weighted F1 = 0.9517
#   Test on FaKES: Weighted F1 = 0.4818
#   Test on FakeVsSatire: Weighted F1 = 0.4998
#   Test on Horne: Weighted F1 = 0.6197
#   Test on Infodemic: Weighted F1 = 0.4743
#   Test on ISOT: Weighted F1 = 0.6918
#   Test on Kaggle_clement: Weighted F1 = 0.6757
#   Test on Kaggle_meg: Weighted F1 = 0.3757
#   Test on LIAR_PLUS: Weighted F1 = 0.4859
#   Test on Politifact: Weighted F1 = 0.4403
#   Test on Unipi_NDF: Weighted F1 = 0.5847
#
# Results after training on FaKES:
#   Test on Celebrity: Weighted F1 = 0.4358
#   Test on CIDII: Weighted F1 = 0.5006
#   Test on FaKES: Weighted F1 = 0.4791
#   Test on FakeVsSatire: Weighted F1 = 0.3263
#   Test on Horne: Weighted F1 = 0.5341
#   Test on Infodemic: Weighted F1 = 0.4384
#   Test on ISOT: Weighted F1 = 0.4015
#   Test on Kaggle_clement: Weighted F1 = 0.4058
#   Test on Kaggle_meg: Weighted F1 = 0.7947
#   Test on LIAR_PLUS: Weighted F1 = 0.4936
#   Test on Politifact: Weighted F1 = 0.4851
#   Test on Unipi_NDF: Weighted F1 = 0.4275
#
# Results after training on FakeVsSatire:
#   Test on Celebrity: Weighted F1 = 0.4998
#   Test on CIDII: Weighted F1 = 0.3641
#   Test on FaKES: Weighted F1 = 0.3016
#   Test on FakeVsSatire: Weighted F1 = 0.7621
#   Test on Horne: Weighted F1 = 0.5003
#   Test on Infodemic: Weighted F1 = 0.3929
#   Test on ISOT: Weighted F1 = 0.4587
#   Test on Kaggle_clement: Weighted F1 = 0.4248
#   Test on Kaggle_meg: Weighted F1 = 0.3685
#   Test on LIAR_PLUS: Weighted F1 = 0.4300
#   Test on Politifact: Weighted F1 = 0.3318
#   Test on Unipi_NDF: Weighted F1 = 0.5079
#
# Results after training on Horne:
#   Test on Celebrity: Weighted F1 = 0.5022
#   Test on CIDII: Weighted F1 = 0.6254
#   Test on FaKES: Weighted F1 = 0.4847
#   Test on FakeVsSatire: Weighted F1 = 0.4418
#   Test on Horne: Weighted F1 = 0.7281
#   Test on Infodemic: Weighted F1 = 0.4789
#   Test on ISOT: Weighted F1 = 0.4658
#   Test on Kaggle_clement: Weighted F1 = 0.5060
#   Test on Kaggle_meg: Weighted F1 = 0.8552
#   Test on LIAR_PLUS: Weighted F1 = 0.5065
#   Test on Politifact: Weighted F1 = 0.6496
#   Test on Unipi_NDF: Weighted F1 = 0.5270
#
# Results after training on Infodemic:
#   Test on Celebrity: Weighted F1 = 0.3333
#   Test on CIDII: Weighted F1 = 0.2723
#   Test on FaKES: Weighted F1 = 0.3042
#   Test on FakeVsSatire: Weighted F1 = 0.4278
#   Test on Horne: Weighted F1 = 0.2020
#   Test on Infodemic: Weighted F1 = 0.9219
#   Test on ISOT: Weighted F1 = 0.3573
#   Test on Kaggle_clement: Weighted F1 = 0.2961
#   Test on Kaggle_meg: Weighted F1 = 0.0842
#   Test on LIAR_PLUS: Weighted F1 = 0.4129
#   Test on Politifact: Weighted F1 = 0.2992
#   Test on Unipi_NDF: Weighted F1 = 0.2542
#
# Results after training on ISOT:
#   Test on Celebrity: Weighted F1 = 0.3552
#   Test on CIDII: Weighted F1 = 0.3400
#   Test on FaKES: Weighted F1 = 0.3606
#   Test on FakeVsSatire: Weighted F1 = 0.5166
#   Test on Horne: Weighted F1 = 0.4934
#   Test on Infodemic: Weighted F1 = 0.4092
#   Test on ISOT: Weighted F1 = 0.9560
#   Test on Kaggle_clement: Weighted F1 = 0.9467
#   Test on Kaggle_meg: Weighted F1 = 0.3026
#   Test on LIAR_PLUS: Weighted F1 = 0.5218
#   Test on Politifact: Weighted F1 = 0.5087
#   Test on Unipi_NDF: Weighted F1 = 0.3041
#
# Results after training on Kaggle_clement:
#   Test on Celebrity: Weighted F1 = 0.3711
#   Test on CIDII: Weighted F1 = 0.3529
#   Test on FaKES: Weighted F1 = 0.3606
#   Test on FakeVsSatire: Weighted F1 = 0.4346
#   Test on Horne: Weighted F1 = 0.4099
#   Test on Infodemic: Weighted F1 = 0.4320
#   Test on ISOT: Weighted F1 = 0.9393
#   Test on Kaggle_clement: Weighted F1 = 0.9519
#   Test on Kaggle_meg: Weighted F1 = 0.3366
#   Test on LIAR_PLUS: Weighted F1 = 0.5329
#   Test on Politifact: Weighted F1 = 0.4989
#   Test on Unipi_NDF: Weighted F1 = 0.3041
#
# Results after training on Kaggle_meg:
#   Test on Celebrity: Weighted F1 = 0.4323
#   Test on CIDII: Weighted F1 = 0.4674
#   Test on FaKES: Weighted F1 = 0.3736
#   Test on FakeVsSatire: Weighted F1 = 0.2687
#   Test on Horne: Weighted F1 = 0.4688
#   Test on Infodemic: Weighted F1 = 0.5041
#   Test on ISOT: Weighted F1 = 0.3399
#   Test on Kaggle_clement: Weighted F1 = 0.4006
#   Test on Kaggle_meg: Weighted F1 = 0.9429
#   Test on LIAR_PLUS: Weighted F1 = 0.4770
#   Test on Politifact: Weighted F1 = 0.6033
#   Test on Unipi_NDF: Weighted F1 = 0.4376
#
# Results after training on LIAR_PLUS:
#   Test on Celebrity: Weighted F1 = 0.4485
#   Test on CIDII: Weighted F1 = 0.3165
#   Test on FaKES: Weighted F1 = 0.4437
#   Test on FakeVsSatire: Weighted F1 = 0.4584
#   Test on Horne: Weighted F1 = 0.4649
#   Test on Infodemic: Weighted F1 = 0.6063
#   Test on ISOT: Weighted F1 = 0.5094
#   Test on Kaggle_clement: Weighted F1 = 0.4811
#   Test on Kaggle_meg: Weighted F1 = 0.4262
#   Test on LIAR_PLUS: Weighted F1 = 0.6037
#   Test on Politifact: Weighted F1 = 0.5432
#   Test on Unipi_NDF: Weighted F1 = 0.3571
#
# Results after training on Politifact:
#   Test on Celebrity: Weighted F1 = 0.4895
#   Test on CIDII: Weighted F1 = 0.6013
#   Test on FaKES: Weighted F1 = 0.4710
#   Test on FakeVsSatire: Weighted F1 = 0.4444
#   Test on Horne: Weighted F1 = 0.5782
#   Test on Infodemic: Weighted F1 = 0.5738
#   Test on ISOT: Weighted F1 = 0.4890
#   Test on Kaggle_clement: Weighted F1 = 0.5240
#   Test on Kaggle_meg: Weighted F1 = 0.8547
#   Test on LIAR_PLUS: Weighted F1 = 0.4808
#   Test on Politifact: Weighted F1 = 0.7786
#   Test on Unipi_NDF: Weighted F1 = 0.3951
#
# Results after training on Unipi_NDF:
#   Test on Celebrity: Weighted F1 = 0.5484
#   Test on CIDII: Weighted F1 = 0.3576
#   Test on FaKES: Weighted F1 = 0.3124
#   Test on FakeVsSatire: Weighted F1 = 0.5493
#   Test on Horne: Weighted F1 = 0.3456
#   Test on Infodemic: Weighted F1 = 0.5380
#   Test on ISOT: Weighted F1 = 0.3986
#   Test on Kaggle_clement: Weighted F1 = 0.3703
#   Test on Kaggle_meg: Weighted F1 = 0.4740
#   Test on LIAR_PLUS: Weighted F1 = 0.5065
#   Test on Politifact: Weighted F1 = 0.5996
#   Test on Unipi_NDF: Weighted F1 = 0.8173

# %% [markdown]
# ## VERSION 2: Dataset by Topic

# %%
dataset_df = data_by_topic()

for topic, df in dataset_df.items():
    print(f"Topic: {topic}, Number of samples: {len(df)}")
# Out:
# Topic: politics, Number of samples: 97476
# Topic: general, Number of samples: 12845
# Topic: covid, Number of samples: 10559
# Topic: syria, Number of samples: 842
# Topic: islam, Number of samples: 722
# Topic: notredame, Number of samples: 554
# Topic: gossip, Number of samples: 500

# %%
# -------------------------------
# Fine-tuning on Dataset by Topic
# -------------------------------

datasets = {topic: split_dataset(df) for topic, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (topic, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on topic: {topic} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after topic {topic}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after topic {topic}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after topic {topic}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all topics
    print("\n--- Evaluation on all topics ---")
    results[topic] = {}
    for test_topic, test_data in datasets.items(): # for each topic
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[topic][test_topic] = f1
        print(f"Evaluation on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# === Phase 1: Training/Fine-tuning on topic: politics ===
# Classification Report after topic politics:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90     10094
#          1.0       0.88      0.90      0.89      9402
#
#     accuracy                           0.90     19496
#    macro avg       0.90      0.90      0.90     19496
# weighted avg       0.90      0.90      0.90     19496
#
# Confusion Matrix after topic politics:
# [[8993 1101]
#  [ 939 8463]]
#
# Weighted F1-score after topic politics: 0.8953868054693163
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.8954
# Evaluation on topic general: Weighted F1 = 0.3275
# Evaluation on topic covid: Weighted F1 = 0.4314
# Evaluation on topic syria: Weighted F1 = 0.3606
# Evaluation on topic islam: Weighted F1 = 0.3781
# Evaluation on topic notredame: Weighted F1 = 0.3041
# Evaluation on topic gossip: Weighted F1 = 0.3763
#
# === Phase 2: Training/Fine-tuning on topic: general ===
# Classification Report after topic general:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96      2514
#          1.0       0.06      0.16      0.09        55
#
#     accuracy                           0.93      2569
#    macro avg       0.52      0.55      0.52      2569
# weighted avg       0.96      0.93      0.94      2569
#
# Confusion Matrix after topic general:
# [[2371  143]
#  [  46    9]]
#
# Weighted F1-score after topic general: 0.9429442020772815
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3831
# Evaluation on topic general: Weighted F1 = 0.9429
# Evaluation on topic covid: Weighted F1 = 0.5041
# Evaluation on topic syria: Weighted F1 = 0.3736
# Evaluation on topic islam: Weighted F1 = 0.4674
# Evaluation on topic notredame: Weighted F1 = 0.4376
# Evaluation on topic gossip: Weighted F1 = 0.4323
#
# === Phase 3: Training/Fine-tuning on topic: covid ===
# Classification Report after topic covid:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92      1106
#          1.0       0.89      0.95      0.92      1006
#
#     accuracy                           0.92      2112
#    macro avg       0.92      0.92      0.92      2112
# weighted avg       0.92      0.92      0.92      2112
#
# Confusion Matrix after topic covid:
# [[992 114]
#  [ 51 955]]
#
# Weighted F1-score after topic covid: 0.9219158392527766
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3432
# Evaluation on topic general: Weighted F1 = 0.0842
# Evaluation on topic covid: Weighted F1 = 0.9219
# Evaluation on topic syria: Weighted F1 = 0.3042
# Evaluation on topic islam: Weighted F1 = 0.2723
# Evaluation on topic notredame: Weighted F1 = 0.2542
# Evaluation on topic gossip: Weighted F1 = 0.3333
#
# === Phase 4: Training/Fine-tuning on topic: syria ===
# Classification Report after topic syria:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.67      0.59        89
#          1.0       0.45      0.30      0.36        80
#
#     accuracy                           0.50       169
#    macro avg       0.49      0.49      0.47       169
# weighted avg       0.49      0.50      0.48       169
#
# Confusion Matrix after topic syria:
# [[60 29]
#  [56 24]]
#
# Weighted F1-score after topic syria: 0.47911089601619866
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4182
# Evaluation on topic general: Weighted F1 = 0.7947
# Evaluation on topic covid: Weighted F1 = 0.4384
# Evaluation on topic syria: Weighted F1 = 0.4791
# Evaluation on topic islam: Weighted F1 = 0.5006
# Evaluation on topic notredame: Weighted F1 = 0.4275
# Evaluation on topic gossip: Weighted F1 = 0.4358
#
# === Phase 5: Training/Fine-tuning on topic: islam ===
# Classification Report after topic islam:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.96        85
#          1.0       0.95      0.93      0.94        60
#
#     accuracy                           0.95       145
#    macro avg       0.95      0.95      0.95       145
# weighted avg       0.95      0.95      0.95       145
#
# Confusion Matrix after topic islam:
# [[82  3]
#  [ 4 56]]
#
# Weighted F1-score after topic islam: 0.951662455665872
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.6590
# Evaluation on topic general: Weighted F1 = 0.3757
# Evaluation on topic covid: Weighted F1 = 0.4743
# Evaluation on topic syria: Weighted F1 = 0.4818
# Evaluation on topic islam: Weighted F1 = 0.9517
# Evaluation on topic notredame: Weighted F1 = 0.5847
# Evaluation on topic gossip: Weighted F1 = 0.5333
#
# === Phase 6: Training/Fine-tuning on topic: notredame ===
# Classification Report after topic notredame:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.99      0.88        68
#          1.0       0.96      0.58      0.72        43
#
#     accuracy                           0.83       111
#    macro avg       0.87      0.78      0.80       111
# weighted avg       0.86      0.83      0.82       111
#
# Confusion Matrix after topic notredame:
# [[67  1]
#  [18 25]]
#
# Weighted F1-score after topic notredame: 0.8172520346433391
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4082
# Evaluation on topic general: Weighted F1 = 0.4740
# Evaluation on topic covid: Weighted F1 = 0.5380
# Evaluation on topic syria: Weighted F1 = 0.3124
# Evaluation on topic islam: Weighted F1 = 0.3576
# Evaluation on topic notredame: Weighted F1 = 0.8173
# Evaluation on topic gossip: Weighted F1 = 0.5484
#
# === Phase 7: Training/Fine-tuning on topic: gossip ===
# Classification Report after topic gossip:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.76      0.67        50
#          1.0       0.68      0.50      0.57        50
#
#     accuracy                           0.63       100
#    macro avg       0.64      0.63      0.62       100
# weighted avg       0.64      0.63      0.62       100
#
# Confusion Matrix after topic gossip:
# [[38 12]
#  [25 25]]
#
# Weighted F1-score after topic gossip: 0.6236395076797884
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4188
# Evaluation on topic general: Weighted F1 = 0.9009
# Evaluation on topic covid: Weighted F1 = 0.5376
# Evaluation on topic syria: Weighted F1 = 0.3956
# Evaluation on topic islam: Weighted F1 = 0.5914
# Evaluation on topic notredame: Weighted F1 = 0.5009
# Evaluation on topic gossip: Weighted F1 = 0.6236

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for topic, res in results.items():
    print(f"\nResults after training on topic {topic}:")
    for test_topic, f1 in res.items():
        print(f"  Test on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on topic politics:
#   Test on topic politics: Weighted F1 = 0.8954
#   Test on topic general: Weighted F1 = 0.3275
#   Test on topic covid: Weighted F1 = 0.4314
#   Test on topic syria: Weighted F1 = 0.3606
#   Test on topic islam: Weighted F1 = 0.3781
#   Test on topic notredame: Weighted F1 = 0.3041
#   Test on topic gossip: Weighted F1 = 0.3763
#
# Results after training on topic general:
#   Test on topic politics: Weighted F1 = 0.3831
#   Test on topic general: Weighted F1 = 0.9429
#   Test on topic covid: Weighted F1 = 0.5041
#   Test on topic syria: Weighted F1 = 0.3736
#   Test on topic islam: Weighted F1 = 0.4674
#   Test on topic notredame: Weighted F1 = 0.4376
#   Test on topic gossip: Weighted F1 = 0.4323
#
# Results after training on topic covid:
#   Test on topic politics: Weighted F1 = 0.3432
#   Test on topic general: Weighted F1 = 0.0842
#   Test on topic covid: Weighted F1 = 0.9219
#   Test on topic syria: Weighted F1 = 0.3042
#   Test on topic islam: Weighted F1 = 0.2723
#   Test on topic notredame: Weighted F1 = 0.2542
#   Test on topic gossip: Weighted F1 = 0.3333
#
# Results after training on topic syria:
#   Test on topic politics: Weighted F1 = 0.4182
#   Test on topic general: Weighted F1 = 0.7947
#   Test on topic covid: Weighted F1 = 0.4384
#   Test on topic syria: Weighted F1 = 0.4791
#   Test on topic islam: Weighted F1 = 0.5006
#   Test on topic notredame: Weighted F1 = 0.4275
#   Test on topic gossip: Weighted F1 = 0.4358
#
# Results after training on topic islam:
#   Test on topic politics: Weighted F1 = 0.6590
#   Test on topic general: Weighted F1 = 0.3757
#   Test on topic covid: Weighted F1 = 0.4743
#   Test on topic syria: Weighted F1 = 0.4818
#   Test on topic islam: Weighted F1 = 0.9517
#   Test on topic notredame: Weighted F1 = 0.5847
#   Test on topic gossip: Weighted F1 = 0.5333
#
# Results after training on topic notredame:
#   Test on topic politics: Weighted F1 = 0.4082
#   Test on topic general: Weighted F1 = 0.4740
#   Test on topic covid: Weighted F1 = 0.5380
#   Test on topic syria: Weighted F1 = 0.3124
#   Test on topic islam: Weighted F1 = 0.3576
#   Test on topic notredame: Weighted F1 = 0.8173
#   Test on topic gossip: Weighted F1 = 0.5484
#
# Results after training on topic gossip:
#   Test on topic politics: Weighted F1 = 0.4188
#   Test on topic general: Weighted F1 = 0.9009
#   Test on topic covid: Weighted F1 = 0.5376
#   Test on topic syria: Weighted F1 = 0.3956
#   Test on topic islam: Weighted F1 = 0.5914
#   Test on topic notredame: Weighted F1 = 0.5009
#   Test on topic gossip: Weighted F1 = 0.6236

# %% [markdown]
# ## VERSION 3: Dataset by Date

# %%
dataset_df = data_by_date()

for date, df in dataset_df.items():
    print(f"Date: {date}, Number of samples: {len(df)}")
# Out:
# Date: 2011-2013, Number of samples: 55
# Date: 2014, Number of samples: 114
# Date: 2015, Number of samples: 84
# Date: 2016, Number of samples: 63018
# Date: 2017, Number of samples: 16657
# Date: 2019, Number of samples: 554
# Date: 2020, Number of samples: 10559

# %%
# ------------------------------
# Fine-tuning on Dataset by Date
# ------------------------------

dataset_df = data_by_date()

datasets = {date: split_dataset(df) for date, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (date, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on date: {date} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after date {date}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after date {date}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after date {date}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all dates
    print("\n--- Evaluation on all dates ---")
    results[date] = {}
    for test_date, test_data in datasets.items(): # for each date
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[date][test_date] = f1
        print(f"Evaluation on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# === Phase 1: Training/Fine-tuning on date: 2011-2013 ===
# Classification Report after date 2011-2013:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50         5
#          1.0       0.50      0.33      0.40         6
#
#     accuracy                           0.45        11
#    macro avg       0.46      0.47      0.45        11
# weighted avg       0.47      0.45      0.45        11
#
# Confusion Matrix after date 2011-2013:
# [[3 2]
#  [4 2]]
#
# Weighted F1-score after date 2011-2013: 0.4454545454545455
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.4455
# Evaluation on date 2014: Weighted F1 = 0.4348
# Evaluation on date 2015: Weighted F1 = 0.7647
# Evaluation on date 2016: Weighted F1 = 0.4851
# Evaluation on date 2017: Weighted F1 = 0.6651
# Evaluation on date 2019: Weighted F1 = 0.5996
# Evaluation on date 2020: Weighted F1 = 0.4152
#
# === Phase 2: Training/Fine-tuning on date: 2014 ===
# Classification Report after date 2014:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.08      0.13        12
#          1.0       0.45      0.82      0.58        11
#
#     accuracy                           0.43        23
#    macro avg       0.39      0.45      0.36        23
# weighted avg       0.39      0.43      0.35        23
#
# Confusion Matrix after date 2014:
# [[ 1 11]
#  [ 2  9]]
#
# Weighted F1-score after date 2014: 0.34726507713884996
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.5377
# Evaluation on date 2014: Weighted F1 = 0.3473
# Evaluation on date 2015: Weighted F1 = 0.5853
# Evaluation on date 2016: Weighted F1 = 0.3803
# Evaluation on date 2017: Weighted F1 = 0.3662
# Evaluation on date 2019: Weighted F1 = 0.5097
# Evaluation on date 2020: Weighted F1 = 0.4644
#
# === Phase 3: Training/Fine-tuning on date: 2015 ===
# Classification Report after date 2015:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.12      0.22         8
#          1.0       0.56      1.00      0.72         9
#
#     accuracy                           0.59        17
#    macro avg       0.78      0.56      0.47        17
# weighted avg       0.77      0.59      0.49        17
#
# Confusion Matrix after date 2015:
# [[1 7]
#  [0 9]]
#
# Weighted F1-score after date 2015: 0.48575163398692806
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.1399
# Evaluation on date 2014: Weighted F1 = 0.3734
# Evaluation on date 2015: Weighted F1 = 0.4858
# Evaluation on date 2016: Weighted F1 = 0.4830
# Evaluation on date 2017: Weighted F1 = 0.8156
# Evaluation on date 2019: Weighted F1 = 0.6557
# Evaluation on date 2020: Weighted F1 = 0.4534
#
# === Phase 4: Training/Fine-tuning on date: 2016 ===
# Classification Report after date 2016:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.80      0.86      7861
#          1.0       0.73      0.89      0.80      4743
#
#     accuracy                           0.84     12604
#    macro avg       0.83      0.85      0.83     12604
# weighted avg       0.85      0.84      0.84     12604
#
# Confusion Matrix after date 2016:
# [[6322 1539]
#  [ 535 4208]]
#
# Weighted F1-score after date 2016: 0.8377111792424499
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.2841
# Evaluation on date 2014: Weighted F1 = 0.3578
# Evaluation on date 2015: Weighted F1 = 0.3012
# Evaluation on date 2016: Weighted F1 = 0.8377
# Evaluation on date 2017: Weighted F1 = 0.9852
# Evaluation on date 2019: Weighted F1 = 0.3045
# Evaluation on date 2020: Weighted F1 = 0.5166
#
# === Phase 5: Training/Fine-tuning on date: 2017 ===
# Classification Report after date 2017:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99      3318
#          1.0       0.14      0.86      0.24        14
#
#     accuracy                           0.98      3332
#    macro avg       0.57      0.92      0.62      3332
# weighted avg       1.00      0.98      0.99      3332
#
# Confusion Matrix after date 2017:
# [[3245   73]
#  [   2   12]]
#
# Weighted F1-score after date 2017: 0.9854406901582207
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.4253
# Evaluation on date 2014: Weighted F1 = 0.3991
# Evaluation on date 2015: Weighted F1 = 0.3665
# Evaluation on date 2016: Weighted F1 = 0.5039
# Evaluation on date 2017: Weighted F1 = 0.9854
# Evaluation on date 2019: Weighted F1 = 0.5163
# Evaluation on date 2020: Weighted F1 = 0.5227
#
# === Phase 6: Training/Fine-tuning on date: 2019 ===
# Classification Report after date 2019:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90        68
#          1.0       0.87      0.79      0.83        43
#
#     accuracy                           0.87       111
#    macro avg       0.87      0.86      0.86       111
# weighted avg       0.87      0.87      0.87       111
#
# Confusion Matrix after date 2019:
# [[63  5]
#  [ 9 34]]
#
# Weighted F1-score after date 2019: 0.8725994286969897
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3850
# Evaluation on date 2014: Weighted F1 = 0.3991
# Evaluation on date 2015: Weighted F1 = 0.3665
# Evaluation on date 2016: Weighted F1 = 0.3418
# Evaluation on date 2017: Weighted F1 = 0.2190
# Evaluation on date 2019: Weighted F1 = 0.8726
# Evaluation on date 2020: Weighted F1 = 0.5276
#
# === Phase 7: Training/Fine-tuning on date: 2020 ===
# Classification Report after date 2020:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.87      0.90      1106
#          1.0       0.87      0.94      0.90      1006
#
#     accuracy                           0.90      2112
#    macro avg       0.90      0.91      0.90      2112
# weighted avg       0.91      0.90      0.90      2112
#
# Confusion Matrix after date 2020:
# [[964 142]
#  [ 61 945]]
#
# Weighted F1-score after date 2020: 0.9039157413734057
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3850
# Evaluation on date 2014: Weighted F1 = 0.3095
# Evaluation on date 2015: Weighted F1 = 0.3665
# Evaluation on date 2016: Weighted F1 = 0.2298
# Evaluation on date 2017: Weighted F1 = 0.0202
# Evaluation on date 2019: Weighted F1 = 0.2855
# Evaluation on date 2020: Weighted F1 = 0.9039

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for date, res in results.items():
    print(f"\nResults after training on date {date}:")
    for test_date, f1 in res.items():
        print(f"  Test on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on date 2011-2013:
#   Test on date 2011-2013: Weighted F1 = 0.4455
#   Test on date 2014: Weighted F1 = 0.4348
#   Test on date 2015: Weighted F1 = 0.7647
#   Test on date 2016: Weighted F1 = 0.4851
#   Test on date 2017: Weighted F1 = 0.6651
#   Test on date 2019: Weighted F1 = 0.5996
#   Test on date 2020: Weighted F1 = 0.4152
#
# Results after training on date 2014:
#   Test on date 2011-2013: Weighted F1 = 0.5377
#   Test on date 2014: Weighted F1 = 0.3473
#   Test on date 2015: Weighted F1 = 0.5853
#   Test on date 2016: Weighted F1 = 0.3803
#   Test on date 2017: Weighted F1 = 0.3662
#   Test on date 2019: Weighted F1 = 0.5097
#   Test on date 2020: Weighted F1 = 0.4644
#
# Results after training on date 2015:
#   Test on date 2011-2013: Weighted F1 = 0.1399
#   Test on date 2014: Weighted F1 = 0.3734
#   Test on date 2015: Weighted F1 = 0.4858
#   Test on date 2016: Weighted F1 = 0.4830
#   Test on date 2017: Weighted F1 = 0.8156
#   Test on date 2019: Weighted F1 = 0.6557
#   Test on date 2020: Weighted F1 = 0.4534
#
# Results after training on date 2016:
#   Test on date 2011-2013: Weighted F1 = 0.2841
#   Test on date 2014: Weighted F1 = 0.3578
#   Test on date 2015: Weighted F1 = 0.3012
#   Test on date 2016: Weighted F1 = 0.8377
#   Test on date 2017: Weighted F1 = 0.9852
#   Test on date 2019: Weighted F1 = 0.3045
#   Test on date 2020: Weighted F1 = 0.5166
#
# Results after training on date 2017:
#   Test on date 2011-2013: Weighted F1 = 0.4253
#   Test on date 2014: Weighted F1 = 0.3991
#   Test on date 2015: Weighted F1 = 0.3665
#   Test on date 2016: Weighted F1 = 0.5039
#   Test on date 2017: Weighted F1 = 0.9854
#   Test on date 2019: Weighted F1 = 0.5163
#   Test on date 2020: Weighted F1 = 0.5227
#
# Results after training on date 2019:
#   Test on date 2011-2013: Weighted F1 = 0.3850
#   Test on date 2014: Weighted F1 = 0.3991
#   Test on date 2015: Weighted F1 = 0.3665
#   Test on date 2016: Weighted F1 = 0.3418
#   Test on date 2017: Weighted F1 = 0.2190
#   Test on date 2019: Weighted F1 = 0.8726
#   Test on date 2020: Weighted F1 = 0.5276
#
# Results after training on date 2020:
#   Test on date 2011-2013: Weighted F1 = 0.3850
#   Test on date 2014: Weighted F1 = 0.3095
#   Test on date 2015: Weighted F1 = 0.3665
#   Test on date 2016: Weighted F1 = 0.2298
#   Test on date 2017: Weighted F1 = 0.0202
#   Test on date 2019: Weighted F1 = 0.2855
#   Test on date 2020: Weighted F1 = 0.9039
