# %% [markdown]
# # Result Plots

# %%
from utils.utils_plot import *

# %%
TOPIC_ORDER = ['politics', 'general', 'covid', 'syria', 'islam', 'notredame', 'gossip'] # Topic order for plots
DATE_ORDER = ['2011-2015', '2016', '2017', '2019', '2020'] # Date order for plots
MODEL_ORDER = ['BERT', 'DeBERTa', 'RoBERTa', 'CNN', 'BiLSTM'] # Model order for plots

# %% [markdown]
# ## Results: Topic (ALPHA 0.5 / DIM 50)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="05", dim=50)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Topic (ALPHA 0.5 / DIM 100)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="05", dim=100)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Topic (ALPHA 0.5 / DIM 200)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="05", dim=200)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Topic (ALPHA 0.3 / DIM = 50)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="03", dim=50)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Topic (ALPHA 0.3 / DIM = 100)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="03", dim=100)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Topic (ALPHA 0.3 / DIM = 200)

# %%
data = load_data(type="topic", dir="dist_rep", alpha="03", dim=200)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_full_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_full_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_cumulative_comparison_tesi(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=TOPIC_ORDER, type="topic")
plot_single_comparisons_start_task(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
plot_task_matrices(data, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_acc_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_bwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=TOPIC_ORDER, type="topic")
plot_fwt_progressive(data, task_order=TOPIC_ORDER, type="topic")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=TOPIC_ORDER, type="topic")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=TOPIC_ORDER, type="topic")

# %% [markdown]
# ## Results: Date (ALPHA 0.5 / DIM 50)

# %%
data = load_data(type='date', dir="dist_rep", alpha="05", dim=50)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")

# %% [markdown]
# ## Results: Date (ALPHA 0.5 / DIM 100)

# %%
data = load_data(type='date', dir="dist_rep", alpha="05", dim=100)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")

# %% [markdown]
# ## Results: Date (ALPHA 0.5 / DIM 200)

# %%
data = load_data(type='date', dir="dist_rep", alpha="05", dim=200)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")

# %% [markdown]
# ## Results: Date (ALPHA 0.3 / DIM 50)

# %%
data = load_data(type='date', dir="dist_rep", alpha="03", dim=50)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")

# %% [markdown]
# ## Results: Date (ALPHA 0.3 / DIM 100)

# %%
data = load_data(type='date', dir="dist_rep", alpha="03", dim=100)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")

# %% [markdown]
# ## Results: Date (ALPHA 0.3 / DIM 200)

# %%
data = load_data(type='date', dir="dist_rep", alpha="03", dim=200)
print(f"Found data for models: {list(data.keys())}")

# Get data for 'CNN', 'BiLSTM'
data_tensorflow = {k: v for k, v in data.items() if k in ['CNN', 'BiLSTM']}
# Get data for 'BERT', 'RoBERTa', 'DeBERTa'
data_torch = {k: v for k, v in data.items() if k in ['BERT', 'RoBERTa', 'DeBERTa']}

# %%
# ALL MODELS
plot_full_comparison(data, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_full_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_full_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_full_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_cumulative_comparison(data, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_cumulative_comparison(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_cumulative_comparison(data_torch, task_order=DATE_ORDER, type='date')
plot_cumulative_comparison_tesi(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_single_comparisons(data, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_single_comparisons(data_tensorflow, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_single_comparisons(data_torch, task_order=DATE_ORDER, type='date')
plot_single_comparisons_start_task(data_torch, task_order=DATE_ORDER, type='date')

# %%
plot_task_matrices(data, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_acc_comparison(data, task_order=DATE_ORDER, type='date')
plot_acc_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_acc_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_acc_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_bwt_comparison(data, task_order=DATE_ORDER, type='date')
plot_bwt_progressive(data, task_order=DATE_ORDER, type='date')

# TENSORFLOW MODELS
plot_bwt_progressive(data_tensorflow, task_order=DATE_ORDER, type='date')

# TORCH MODELS
plot_bwt_progressive(data_torch, task_order=DATE_ORDER, type='date')

# %%
# ALL MODELS
plot_fwt_comparison(data, task_order=DATE_ORDER, type="date")
plot_fwt_progressive(data, task_order=DATE_ORDER, type="date")

# TENSORFLOW MODELS
plot_fwt_progressive(data_tensorflow, task_order=DATE_ORDER, type="date")

# TORCH MODELS
plot_fwt_progressive(data_torch, task_order=DATE_ORDER, type="date")
